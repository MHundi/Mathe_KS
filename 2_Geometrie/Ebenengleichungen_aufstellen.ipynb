# %% [markdown]
# ## 3 Punkte $\rightarrow$ Koordinatengleichung
#
# $$
# A(1|3| 2), B(-1|2| 1), C(3|-2|-1)
# $$
#
# Allgemeine Ebenengleichung:
# $$E: a x_{1}+b x_{2}+c x_{3}=d$$
#
# Einsetzen der Punkte:
#
# \begin{center}
# \includegraphics[max width=\textwidth]{2024_06_17_b1747c9549853b7441fag-1}
# \end{center}
#
# $$
# \begin{aligned}
# & 3 a-2 b-c&=&d \\
# & a+3 b+2 c&=&d \\
# \\
#
# &5 b+3 c&=&2 d \\
# & 11 b+7 c&=&2 d \\
# & a+3 b+2 c&=&d \\
# & 5 b+3 c&=&2 d \\
# & -2 c&=&12 d \quad \text { wähle } d=1 \\
# & -2 c&=&12 \\
# \Leftrightarrow &\quad c&=&-6 \\
#  56+3(-6)&=&2 \\
#  \Leftrightarrow& 56-18=2 \\
#  \Leftrightarrow &\quad 5 b=20 \\
#  \Leftrightarrow & \quad \underline{\underline{b}=4} \\
# & a+3 \cdot 4+2 \cdot(-6)=1 \\
# & \Leftrightarrow a+12-12=1 \\
# & \Leftrightarrow \quad \underline{a}=1 \\
# & E: \quad x_{1}+4 x_{2}-6 x_{3}=1
# \end{aligned}
# $$
#
# 3 Punkte $\rightarrow$ Normalengleichung
#
# Itützuerlor wäklen, $2 . B \overrightarrow{O H}$
#
# $$
# E:\left[\vec{x}-\left(\begin{array}{l}
# 1 \\
# 3 \\
# 2
# \end{array}\right)\right] \cdot\left(\begin{array}{l}
# n_{1} \\
# n_{2} \\
# n_{3}
# \end{array}\right)=0
# $$
#
# Siche vertor $\vec{n}=\left(\begin{array}{l}n_{1} \\ n_{2} \\ n_{3}\end{array}\right)$, so das $n \perp \overrightarrow{F B}$ und
#
# $\perp \overrightarrow{H C}$
#
# $$
# \overrightarrow{A B}=\left(\begin{array}{l}
# -2 \\
# -1 \\
# -1
# \end{array}\right), \quad \overrightarrow{A C}=\left(\begin{array}{c}
# 2 \\
# -5 \\
# -3
# \end{array}\right)
# $$
#
# Fues $\overrightarrow{A B} \perp \vec{n}$ und $\overrightarrow{H C} \perp \vec{n}$ folgt:
#
# $\overrightarrow{A B} \circ \vec{h}=0$ und $\overrightarrow{H C} \circ \vec{n}=0$
#
#
# \begin{align*}
# & -2 n_{1}-1 n_{2}-1 n_{3}=0 \\
# & 2 n_{1}-5 n_{2}-3 n_{3}=0 \\
# & -2 n_{1}-n_{2}-n_{3}=0 \\
# & -6 n_{2}-4 n_{3}=0 \\
# & -6 n_{2}-4 n_{3}=01: 2 \\
# & \Leftrightarrow-3 n_{2}-2 n_{3}=0 \\
# & \Leftrightarrow \quad-3 n_{2}-2 t=0 \\
# & \Leftrightarrow \quad-3 n_{2}=2 t \\
# & \Leftrightarrow \quad n_{2}=-\frac{2}{3} t \\
# & -2 n_{1}+\frac{2}{3} t-t=0 \\
# & \Leftrightarrow-2 n 1-\frac{1}{3} t=0 \\
# & \Leftrightarrow \quad-2 u_{1}=\frac{1}{3} t \\
# & \Leftrightarrow \quad n_{1}=-\frac{1}{6} t \quad \text { wähle } t=6
# \end{align*}
#
#
# $z=\left(\begin{array}{l}n \\ n_{1} \\ n_{3}\end{array}\right)=\binom{1}{-y} \rightarrow$ Unsereche Poramela la. Koondenatitn. foichung
#
# $$
# E\left[\vec{x}-\left(\begin{array}{l}
# 1 \\
# 3 \\
# 2
# \end{array}\right)\right] \cdot\left(\begin{array}{l}
# 1 \\
# 4 \\
# 6
# \end{array}\right)=0
# $$
#
# $\rightarrow$ Uriberprochit modhl es sdametier
#
# 3 Punile $\rightarrow$ Panamelugleidhung wáhle einsen Pumil als Jhata
#
# $$
# E \quad \vec{x}=\left(\begin{array}{l}
# 1 \\
# 3 \\
# 2
# \end{array}\right) \cdot 6\left(\begin{array}{c}
# 2 \\
# -1 \\
# -1
# \end{array}\right) \times 1\left(\begin{array}{c}
# 2 \\
# -3 \\
# 3
# \end{array}\right)
# $$
#
# Besondere Ebonsugleidiwugen
#
# \begin{center}
# \includegraphics[max width=\textwidth]{2024_06_17_b1747c9549853b7441fag-3}
# \end{center}
#
# $\underline{x_{1}-x_{3}-\text { EbPhe: }}$
#
# Paramelengleichung $E \quad \vec{x}=\left(\begin{array}{l}0 \\ 0 \\ 0\end{array}\right)+t\left(\begin{array}{l}1 \\ 0 \\ 0\end{array}\right)+s\left(\begin{array}{l}0 \\ 0 \\ 1\end{array}\right), t, s \in R$
#
# Normalengleichung $\vec{E}:\left[\vec{X}-\left(\begin{array}{l}0 \\ 0 \\ 0\end{array}\right)\right] 0\left(\begin{array}{l}0 \\ 1 \\ 0\end{array}\right)=0$
#
# $$
# E: \quad \times 0\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right)=0
# $$
#
# Koordinatengleichung: $E . \quad x_{2} \geq 0$\\
# $x_{1}-x_{2}-$ Ebere
#
# Paramelenglichung $\quad E \quad \vec{x}=t\left(\begin{array}{l}1 \\ 0 \\ 0\end{array}\right)+3\left(\begin{array}{l}0 \\ 1 \\ 0\end{array}\right), s, t \in \mathbb{R}$
#
# Normalengleichury E $\quad \vec{x} \cdot\left(\begin{array}{l}0 \\ 0 \\ 1\end{array}\right)=0$
#
# Kocrdinatengleichang $E \quad x_{3}=0$
#
# $x_{2}=x_{3}$-Ebrue
#
# Paramelengleichung $\mathrm{E} \quad \hat{x} *\left(\begin{array}{l}0 \\ 1 \\ 0\end{array}\right) \cdots\left(\begin{array}{l}0 \\ 0 \\ 1\end{array}\right), 1+\mathbb{R}$ Vormalengleichung $E \quad 3 \cdot\left(\begin{array}{l}0 \\ 0 \\ 0\end{array}\right)$
#
# Koordinatengleichary $E: \quad x_{n}=0$
#
# Ebenen parcullel zu den Koordinalonslenen
#
# Poramelengleichung $E \quad \vec{x} \cdot\left(\begin{array}{l}d_{1} \\ d_{1} \\ d_{1}\end{array}\right)+t\left(\begin{array}{l}1 \\ 0 \\ 0\end{array}\right)+s\binom{0}{d_{d}}, s, t \in \mathbb{R}$
#
# $$
# \begin{aligned}
# & E \quad \vec{x}=\left(\begin{array}{l}
# d_{1} \\
# d_{1} \\
# d_{3}
# \end{array}\right) \cdot\left(\left(\begin{array}{l}
# 1 \\
# 0 \\
# 0
# \end{array}\right)+1\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right) \cdot s, t \in \mathbb{R}\right. \\
# & E \quad \vec{x}=\left(\begin{array}{l}
# d_{1} \\
# d_{2} \\
# d_{3}
# \end{array}\right)+1\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right)+s\left(\begin{array}{l}
# 0 \\
# 0 \\
# 1
# \end{array}\right), \operatorname{sik}
# \end{aligned}
# $$
#
# Vormalengleichung: $\vec{E} \quad \vec{x} \circ\left(\begin{array}{l}0 \\ 1 \\ 0\end{array}\right)=d$\\
# E. $\quad \vec{x} \cdot\left(\begin{array}{l}0 \\ 0 \\ 1\end{array}\right)=d$
#
# $\bar{E} \quad \vec{x} \cdot\left(\begin{array}{l}1 \\ 0 \\ 0\end{array}\right)=d$
#
# Koor dinatenglichung:
#
# $$
# \begin{array}{ll}
# E: & x_{2}=d \\
# E: & x_{3}=d \\
# E: & x_{1}=d
# \end{array}
# $$
#
# Umformungen
#
# \begin{enumerate}
#   \item Parametenform $\rightarrow$ Normalenform
# \end{enumerate}
#
# $$
# E: \vec{x}=\left(\begin{array}{l}
# 2 \\
# 1 \\
# 2
# \end{array}\right)+r\left(\begin{array}{l}
# 1 \\
# 3 \\
# 0
# \end{array}\right)+s\left(\begin{array}{c}
# -2 \\
# 1 \\
# 3
# \end{array}\right)
# $$
#
# $\vec{h}$ sei ein Normalenvertor won $E$
#
# Damit gilt:
#
# $$
# \vec{u} \circ\left(\begin{array}{l}
# 1 \\
# 3 \\
# 0
# \end{array}\right)=0 \text { und } \vec{u} \circ\left(\begin{array}{c}
# -2 \\
# 1 \\
# 3
# \end{array}\right)=0
# $$
#
# $\Leftrightarrow \quad n_{1}+3 n_{2}=0 \quad$ und $\quad-2 n_{1}+n_{2}+n_{3}=\sigma$
#
# LGS:
#
# $$
# \begin{aligned}
# & -2 n_{1}+n_{2}+n_{3}=0 \\
# & n_{1}+3 n_{2}=\sigma \\
# & n_{1}=-3 n_{2} \\
# & -2\left(-3 n_{2}\right)+n_{2}+3 n_{3}=\sigma \\
# & \Leftrightarrow \quad 6 n_{2}+n_{2}+3 n_{3}=0 \\
# & \Leftrightarrow \\
# & n_{3}=-\frac{7}{3} n_{2}
# \end{aligned}
# $$
#
# setre $n_{2}=3$
#
# $$
# \begin{aligned}
# & \Rightarrow \underline{\underline{n_{3}=-7}} \\
# & \Rightarrow=\underline{n_{1}=-9} \\
# & \vec{n}=\left(\begin{array}{c}
# -9 \\
# 3 \\
# -7
# \end{array}\right)
# \end{aligned}
# $$
#
# $\operatorname{damit}\left[\vec{x}-\left(\begin{array}{l}2 \\ 1 \\ 2\end{array}\right)\right] \cdot\left(\begin{array}{c}-9 \\ 3 \\ -7\end{array}\right)=\sigma$
#
# \begin{enumerate}
#   \setcounter{enumi}{1}
#   \item Normalenform $\rightarrow$ Parameterform
# \end{enumerate}
#
# $$
# \begin{aligned}
# & E:\left[\vec{x}-\left(\begin{array}{c}
# 1 \\
# 2 \\
# 4
# \end{array}\right)\right] \circ\left(\begin{array}{l}
# 1 \\
# 1 \\
# 1
# \end{array}\right)=\sigma \\
# & \text { Stütuvertor } \vec{p}=\left(\begin{array}{c}
# -1 \\
# 2 \\
# 4
# \end{array}\right)
# \end{aligned}
# $$
#
# Spannwertoren sind orthogonal zum Normalenweltor $\vec{n}$ d.h. Finspann wertor $\vec{u}$ fier Spannwertor $\vec{v}$
#
# $$
# \begin{aligned}
# & \vec{u} \circ \vec{n}=\sigma \\
# & \vec{v} \circ \vec{n}=0 \\
# & \Leftrightarrow \quad u_{1} \cdot n_{1}+u_{2} \cdot n_{2}+u_{3} \cdot n_{3}=0 \quad v_{1} \cdot n_{1}+u_{2} \cdot n_{2}+v_{3} \cdot n_{3}=\sigma \\
# & \Leftrightarrow \quad u_{1}+u_{2}+u_{3}=0 \quad v_{1}+v_{2}+v_{3}=\sigma
# \end{aligned}
# $$
#
# wäble $u_{1}=0$ und $u_{2}=1 \quad$ wàle $v_{1}=2$ und $v_{2}=0$
#
# $$
# \begin{array}{llll}
# \Rightarrow & u_{3}=-1 & \Rightarrow & v_{3}=-2 \\
# \Rightarrow & \vec{u}=\left(\begin{array}{c}
# 0 \\
# 1 \\
# -1
# \end{array}\right) & \Rightarrow & \vec{v}=\left(\begin{array}{c}
# 2 \\
# 0 \\
# -2
# \end{array}\right) \\
# E: & \vec{x}=\left(\begin{array}{c}
# -1 \\
# 2 \\
# 4
# \end{array}\right)+i\left(\begin{array}{c}
# 0 \\
# 1 \\
# -1
# \end{array}\right)+s\left(\begin{array}{c}
# 2 \\
# 0 \\
# -2
# \end{array}\right) & \quad \text { in,s } \mathbb{R}
# \end{array}
# $$
#
# 3.) Koordinatengleichung $\rightarrow$ vormalenform
#
# allgemein: $E$ : $a_{1} x_{1}+a_{2} x_{2}+a_{3} x_{3}=b$
#
# $$
# \Leftrightarrow \begin{aligned}
# \Leftrightarrow\left(\begin{array}{l}
# a_{1} \\
# a_{2} \\
# a_{3}
# \end{array}\right) \circ\left(\begin{array}{l}
# x_{1} \\
# x_{2} \\
# x_{3}
# \end{array}\right) & =b \dot{b} \\
# \vec{a} \circ \vec{x} & =b
# \end{aligned}
# $$
#
# Es gibt bestimml einen Vertor $\vec{P}$, so da $\beta$
#
# $$
# \vec{p} 0 \vec{a}=b
# $$
#
# gell.
#
# Dann gilt auch:
#
# $$
# \begin{array}{ll}
# & \vec{a} \circ \vec{x}=\vec{p} \circ \vec{a} \\
# & \vec{a} \circ \vec{x}-\vec{p} \circ \vec{a}=0 \\
# \Leftrightarrow \quad & (\vec{x}-\vec{p}) \circ \vec{a}=0
# \end{array}
# $$
#
# $\Rightarrow \quad \vec{a}$ ist Normalenveltor
#
# $$
# \vec{a}=\left(\begin{array}{l}
# a_{1} \\
# a_{2} \\
# a_{3}
# \end{array}\right) \text { is Normalinveltor }
# $$
#
# Yatz: Gegeben: $E: a_{1} x_{1}+a_{2} x_{2}+a_{3} x_{3}=b$
#
# Dann gilt:
#
# $\vec{n}=\left(\begin{array}{l}a_{1} \\ a_{2} \\ a_{3}\end{array}\right)$ ist lin bormalen wertor der Ebshe E.
#
# $$
# \begin{aligned}
# & E: 2 x_{1}+3 x_{2}+5 x_{3}=10 \\
# & \Rightarrow \quad \vec{n}=\left(\begin{array}{l}
# 2 \\
# 3 \\
# 5
# \end{array}\right)
# \end{aligned}
# $$
#
# Bestimme Stintwerterpuon E:
#
# $$
# \begin{gathered}
# \text { I: }\left[\vec{x}-\left(\begin{array}{l}
# p_{1} \\
# p_{2} \\
# p_{3}
# \end{array}\right)\right] \cdot\left(\begin{array}{l}
# 2 \\
# 3 \\
# 5
# \end{array}\right)=0 \\
# 2 \cdot x_{1}+3 \cdot x_{2}+5 x_{3}=10
# \end{gathered}
# $$
#
# wäkle $x_{1}=0$ und $x_{3}=0$ geschickt:
#
# $$
# \begin{aligned}
# 5 x_{3} & =10 \\
# x_{3} & =2
# \end{aligned}
# $$
#
# $$
# \begin{aligned}
# \vec{p} & =\left(\begin{array}{l}
# 0 \\
# 0 \\
# 2
# \end{array}\right) \\
# E: \quad & {\left[\vec{x}-\left(\begin{array}{l}
# 0 \\
# 0 \\
# 2
# \end{array}\right)\right] \circ\left(\begin{array}{l}
# 2 \\
# 3 \\
# 5
# \end{array}\right)=\sigma }
# \end{aligned}
# $$
#
# 4.) Normalenform $\rightarrow$ Koordinatengleichung
#
# $$
# \begin{aligned}
# & E:\left[\vec{x}-\left(\begin{array}{c}
# -1 \\
# 2 \\
# 5
# \end{array}\right)\right] 0\left(\begin{array}{c}
# 4 \\
# 5 \\
# -1
# \end{array}\right)=\sigma \\
# & E:\left[\left(\begin{array}{l}
# x_{1} \\
# x_{2} \\
# x_{3}
# \end{array}\right)-\left(\begin{array}{c}
# -1 \\
# 2 \\
# 5
# \end{array}\right)\right] 0\left(\begin{array}{c}
# 4 \\
# 5 \\
# -1
# \end{array}\right)=\sigma \\
# & \Leftrightarrow \quad\left(\begin{array}{l}
# x_{1} \\
# x_{2} \\
# x_{3}
# \end{array}\right) \circ\left(\begin{array}{c}
# 4 \\
# 5 \\
# -1
# \end{array}\right)-\left(\begin{array}{c}
# -1 \\
# 2 \\
# 5
# \end{array}\right) \circ\left(\begin{array}{c}
# 4 \\
# 5 \\
# -1
# \end{array}\right)=0 \\
# & \Leftrightarrow \quad E: \quad\left(\begin{array}{l}
# x_{1} \\
# x_{2} \\
# x_{3}
# \end{array}\right) 0\left(\begin{array}{c}
# 4 \\
# 5 \\
# -1
# \end{array}\right)=\left(\begin{array}{c}
# -1 \\
# 2 \\
# 5
# \end{array}\right) 0\left(\begin{array}{c}
# 4 \\
# 5 \\
# -1
# \end{array}\right) \\
# & \Leftrightarrow \quad 4 x_{1}+5 x_{2}-x_{3}=1
# \end{aligned}
# $$
#
# 5.) Koordinatengleichung $\rightarrow$ Parameterglichung
#
# $$
# \begin{array}{ll}
# E: & 2 x_{1}-3 x_{2}+x_{3}=6 \\
# \Leftrightarrow & x_{1}=3+\frac{3}{2} x_{2}-\frac{1}{2} x_{3}
# \end{array}
# $$
#
# Ergänze zumLGS mil 2 wakren Auragen
#
# $$
# \begin{array}{ll}
# x_{1}=3+\frac{3}{2} x_{2}-\frac{1}{2} x_{3} \\
# x_{2}= & x_{2} \\
# x_{3}= & x_{3}
# \end{array}
# $$
#
# $$
# \begin{aligned}
# \Rightarrow E:\left(\begin{array}{l}
# x_{1} \\
# x_{2} \\
# x_{3}
# \end{array}\right) & =\left(\begin{array}{c}
# 3+\frac{3}{2} x_{2}-\frac{1}{2} x_{3} \\
# 0+x_{2}+0 \\
# 0+0+x_{3}
# \end{array}\right) \\
# & =\left(\begin{array}{l}
# 3 \\
# 0 \\
# 0
# \end{array}\right)+\left(\begin{array}{c}
# 3 / 2 x_{2} \\
# x_{2} \\
# 0
# \end{array}\right)+\left(\begin{array}{c}
# -1 / 2 x_{3} \\
# 0 \\
# x_{3}
# \end{array}\right) \\
# & =\left(\begin{array}{l}
# 3 \\
# 0 \\
# 0
# \end{array}\right)+\gamma\left(\begin{array}{c}
# 3 / 2 \\
# 1 \\
# 0
# \end{array}\right)+s\left(\begin{array}{c}
# -1 / 2 \\
# 0 \\
# 1
# \end{array}\right) \quad 1 \gamma=x_{1} s=x_{3}
# \end{aligned}
# $$
#
# \begin{enumerate}
#   \setcounter{enumi}{5}
#   \item Paramelengliichung $\rightarrow$ Koordinatengleichung
# \end{enumerate}
#
# $$
# \begin{aligned}
# & E: \quad \vec{x}=\left(\begin{array}{l}
# 4 \\
# 9 \\
# 1
# \end{array}\right)+r\left(\begin{array}{l}
# 1 \\
# 2 \\
# 0
# \end{array}\right)+s\left(\begin{array}{l}
# 1 \\
# 0 \\
# 3
# \end{array}\right) \\
# & \left(\begin{array}{l}
# x_{1} \\
# x_{2} \\
# x_{3}
# \end{array}\right)=\left(\begin{array}{l}
# 4+\gamma+s \\
# 9+2 \gamma+3 s \\
# 1+2+3
# \end{array}\right) \\
# & \text { LGS: } \left.\begin{array}{rl}
# x_{1} & =4+r+5 \quad \mid(-2) \\
# x_{2} & =9+2 r
# \end{array}\right](1) \\
# & \begin{array}{l}
# x_{3}=1+3 s \\
# x_{1}=4+r+5
# \end{array}
# \end{aligned}
# $$
#
# \begin{center}
# \includegraphics[max width=\textwidth]{2024_06_17_b1747c9549853b7441fag-9}
# \end{center}
#
# $$
# \begin{aligned}
# & x_{1}=4+\lambda+5 \\
# & -2 x_{1}-x_{2}=1 \quad-2 s \\
# & E:-6 x_{1}+3 x_{2}+2 x_{3}=5
# \end{aligned}
# $$
#
#
# \end{document}

# %% [markdown]
# ## 3 Punkte $\rightarrow$ Koordinatengleichung
#
# $$
# A(1|3| 2), B(-1|2| 1), C(3|-2|-1)
# $$
#
# Allgemeine Ebenengleichung:
#
# $$E: a x_{1}+b x_{2}+c x_{3}=d$$
#
# Einsetzen der Punkte:
#
# $$
# \begin{aligned}
# & a + 3b +2c &=& d\\
# & -a+2b+c&=& d\\
# & 3 a-2 b-c&=&d \\
# \\
# & a+3 b+2 c&=&d \\
# &5 b+3 c&=&2 d \\
# & 11 b+7 c&=&2 d \\
# \\
# & a+3 b+2 c&=&d \\
# & 5 b+3 c&=&2 d \\
# & -2 c&=&12 d \quad \text { wähle } d=1 \\\\
#
# & -2 c&=&12 \\
# \Leftrightarrow & &\underline{\underline{c=-6}} \\\\
#
#  & 56+3(-6) &=&2 \\
#  \Leftrightarrow & 56-18&=&2 \\
#  \Leftrightarrow & 5 b&=&20 \\
#  \Leftrightarrow && \underline{\underline{b=4}} \\
#  \\
# & a+3 \cdot 4+2 \cdot(-6)&=&1 \\
#  \Leftrightarrow & a+12-12&=&1 \\
#  \Leftrightarrow && \underline{\underline{a=1}} \\
#  E: \quad x_{1}+4 x_{2}-6 x_{3}=1
# \end{aligned}
# $$
